# %%
from IPython.display import Image

# %%
# %cd darknet
# Out:
# /content/darknet

# %% [markdown]
# #### Loading the latest model weights saved after the training loop.
# Saved in the Google Drive, [here](https://drive.google.com/open?id=1_Osl334n0eUwlnq8U8kzRjh7HmbFBkVe).
# File Size: 235 MB

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1_Osl334n0eUwlnq8U8kzRjh7HmbFBkVe' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1_Osl334n0eUwlnq8U8kzRjh7HmbFBkVe" -O backup/custom_yolov3_last.weights && rm -rf /tmp/cookies.txt
# Out:
# --2019-08-27 15:45:50--  https://docs.google.com/uc?export=download&confirm=iwhW&id=1_Osl334n0eUwlnq8U8kzRjh7HmbFBkVe
# Resolving docs.google.com (docs.google.com)... 74.125.23.101, 74.125.23.138, 74.125.23.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.23.101|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0c-90-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qmd08fk93f9anb8og9hk1a9nh9tdvo54/1566914400000/00369660752892953074/*/1_Osl334n0eUwlnq8U8kzRjh7HmbFBkVe?e=download [following]
# ...
# --2019-08-27 15:45:50--  https://doc-0c-90-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/qmd08fk93f9anb8og9hk1a9nh9tdvo54/1566914400000/00369660752892953074/*/1_Osl334n0eUwlnq8U8kzRjh7HmbFBkVe?e=download
# Resolving doc-0c-90-docs.googleusercontent.com (doc-0c-90-docs.googleusercontent.com)... 108.177.97.132, 2404:6800:4008:c00::84
# ...

# %%
# !head test.txt
# Out:
# /content/darknet/images/0170.jpeg
# /content/darknet/images/0231.jpeg
# /content/darknet/images/0097.jpeg
# /content/darknet/images/0037.jpeg
# /content/darknet/images/0033.jpeg
# /content/darknet/images/0168.jpeg
# /content/darknet/images/0134.jpeg
# /content/darknet/images/0018.jpeg
# /content/darknet/images/0061.jpeg
# /content/darknet/images/0181.jpeg

# %%
# !./darknet detector test cfg/objects.data cfg/custom_yolov3.cfg backup/custom_yolov3_last.weights 'images/0123.jpeg'  -dont_show
# Out:
#  compute_capability = 370, cudnn_half = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
# ...

# %%
Image('predictions.jpg')

# %% [markdown]
# Passing a challenging test case.

# %%
# !./darknet detector test cfg/objects.data cfg/custom_yolov3.cfg backup/custom_yolov3_last.weights 'images/0132.jpeg'  -dont_show
# Out:
#  compute_capability = 370, cudnn_half = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
# ...

# %%
Image('predictions.jpg')
