# %% [markdown]
# #### Cloning the darknet framework repository

# %%
# !git clone https://github.com/AlexeyAB/darknet.git
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 10750 (delta 0), reused 2 (delta 0), pack-reused 10740
# Receiving objects: 100% (10750/10750), 10.33 MiB | 5.82 MiB/s, done.
# Resolving deltas: 100% (7259/7259), done.

# %%
# %cd darknet
# Out:
# /content/darknet

# %%
# !make

# %%
# !./darknet
# Out:
# usage: ./darknet <function>

# %% [markdown]
# #### Downloading the pretrained weights.

# %%
# !wget https://pjreddie.com/media/files/yolo.weights
# Out:
# --2019-08-27 15:24:31--  https://pjreddie.com/media/files/yolo.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 203934260 (194M) [application/octet-stream]
# Saving to: ‘yolo.weights’
#
# yolo.weights        100%[===================>] 194.49M  22.2MB/s    in 9.5s
#
# 2019-08-27 15:24:42 (20.5 MB/s) - ‘yolo.weights’ saved [203934260/203934260]

# %% [markdown]
# #### Performing a prediction on the sample image provided by the framework.

# %%
# !./darknet detect cfg/yolo.cfg yolo.weights data/dog.jpg -dont_show
# Out:
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 max               2 x 2/ 2    416 x 416 x  32 ->  208 x 208 x  32 0.006 BF
#    2 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    3 max               2 x 2/ 2    208 x 208 x  64 ->  104 x 104 x  64 0.003 BF
#    4 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    5 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    6 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    7 max               2 x 2/ 2    104 x 104 x 128 ->   52 x  52 x 128 0.001 BF
#    8 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
#    9 conv    128       1 x 1/ 1     52 x  52 x 256 ->   52 x  52 x 128 0.177 BF
#   10 conv    256       3 x 3/ 1     52 x  52 x 128 ->   52 x  52 x 256 1.595 BF
# ...

# %%
from IPython.display import Image
Image('predictions.jpg')
